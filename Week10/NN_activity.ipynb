# %% [markdown]
# # Neural Networks
#
# In this activity, we will construct a single layer neural network by hand:
#
# <img src="NN.jpeg" width="600" />
#
# Looking closer at a singe node:
#
# <img src="node.jpeg" width="400" />
# We can write the output of the node as:
# $$v = activation(w_1 x_1 + w_2 x_2 + b)$$
#
# For the purposes of this activity, let's choose the sigmoid activation function:
#
# $$activation(z) = \frac{1}{1+e^{-z}}$$
#
# Similary, the linear node:
#
# <img src="linear.jpeg" width="400" />
# gives:
# $$\hat{y} = a_1v_1 + a_2v_2$$
#
#
# ### Step 1:
#
# Complete the constructor and `forward_pass` functions in the `Node` and `Linear` classes.
#
# ### Step 2:
#
# Use these classes to build a neural network make predictions from the synthetic dataset for an *untrained* neural network with 1) two nodes and 2) 20 nodes.
#
# ### Step 3:
#
# Build the same model using the `keras` subpackage in `TensorFlow`
#
# ### Step 3:
#
# Complete the `update weights` and `gradients out` functions (when applicable) for a modularized gradient descent algorithm
#
# ### Step 4:
#
# Use all functions in the class to train your 2-node neural network. You can be as flexible as you like here (e.g. create a `NeuralNetwork` class that encapculates the training for any number of nodes.. or not!

# %%
# place imports here
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# First, let's construct some synthetic data to use for our model. Our model will be general to any input data, but we will generate data with a known mapping that will help with debugging:

# %%
x = np.random.random((1000,2))-.5 # uniform random features between -0.5 and +0.5
y = 3*x[:,0]+.5*x[:,1] # data follows y = 3x1 + 0.5x2

# plot data
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(x[:,0],x[:,1],y)
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_zlabel('$y$')
fig.show()

# %% [markdown]
# ### Define your classes here:

# %%
class Node:
    """
    class for a neural network node with a sigmoid activation function
    
    """
    
    def __init__(self, N, activation="sigmoid"):
        """
        constructor
        
        arguments:
            N:          INT
                        number of inputs to linear node
            activation: STRING
                        type of activation function 
        """
        
        # complete me
        # define weights, activation, and gradients here

        
    def forward_pass(self,inputs):
        """
        returns output of node
        
        arguments:
            inputs: array of FLOAT
        return:
            output: FLOAT
                    
        """
        if self.activation == "sigmoid":
            # complete me
            
            return
        else:
            print("no support for this activation yet")
    def update_weights(self, input_grads, data):
        """
        Update weights
        
        arguments: arrays of FLOAT: input_grads, data
            
        return: None
        
        """
        # complete me
        # update weights here

            
            self.weights[i] = self.weights[i] - eta*chain[i]
    def gradients_out(self):
        return
        
        
        
    
class Linear:
    """
    Output node for a regression problem
    
    """
    def __init__(self,N):
        """
        constructor
        
        arguments:
            N:  INT
                number of inputs to linear node
        """
        # define weights and gradients here

    def forward_pass(self,inputs):
        """
        returns output from a forward pass through the node
        
        arguments:
            inputs: array of FLOAT
                    inputs to the node
            return: FLOAT
                    output of node
        """
        # complete me
        
        return 
    def gradients_out(self):
        """
        returns gradients to pass backwards
        
        inputs:  None
        outputs: array of FLOAT
                 gradients
        
        """
        # complete me
        return

# %% [markdown]
# ## Use your classes to build a neural network:

# %%
# complete me

# %% [markdown]
# ## Make a forward pass through your network:

# %%
# complete me

# %% [markdown]
# ## Use `keras` from `TensorFlow` to build the same model.
#
# Check online documentation for a `Sequential` model, and use `model.summary()` to print details about your model. Do not train yet!

# %%
import tensorflow.keras as keras

model = keras.Sequential()
model.add(keras.layers.Dense(1, input_shape=(2,), activation="linear"))
model.compile()
model.build()
model.summary()
